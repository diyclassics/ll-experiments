# %% [markdown]
# # Finding Magic Squares in the Latin Library
#
# Following: Filho, W. 2018. “Finding Magic Word Squares.” *Code Energy* blog post. https://code.energy/finding-magic-word-squares/.
#
# This notebook does the following:
# - Gets all four and five letter words from the Latin Library (with frequency > 3)
# - Checks letter positions to see if magic square can be made from available words
# - Prints a random square
#
# Inspired by @SarahEBond's 9.13.19 tweet: https://twitter.com/SarahEBond/status/1172256207408697344.
#
# \[PJB 9.13.19\]

# %%
# imports
from collections import Counter
from random import sample
from cltk.corpus.readers import get_corpus_reader
from ll_tools import preprocess

# %%
# set up corpus

ll = get_corpus_reader(corpus_name = 'latin_text_latin_library', language = 'latin')
ll_raw = ll.raw()
ll_pp = preprocess(ll_raw)
ll_words = ll_pp.split()
ll_words_freq = [word for word, count in Counter(ll_words).most_common() if count > 3]

# %%
# helper functions

rev = lambda w: "".join(reversed(list(w)))

# %%
# get valid four-letter words

ll_words_four = set([word for word in ll_words_freq if len(word) == 4])
ll_words_four_valid = [w for w in ll_words_four if rev(w) in ll_words_four]

# %%
# produce four-letter squares

four_squares = []
for w1 in ll_words_four_valid:
    w2_match = lambda x: x[0] == w1[1] and x[-1] == w1[-2]
    for w2 in filter(w2_match, ll_words_four_valid):
        square = [w1, w2, rev(w2), rev(w1)]
        four_squares.append(square)

print(f'There are {len(four_squares)} that can be created from the Latin Library from four-letter words appearing more than 3x.')
# Out:
# There are 489 that can be created from the Latin Library from four-letter words appearing more than 3x.

# %%
# print random square

example = sample(four_squares, 1)[0]
for w in example:
    print(w)
# Out:
# same
# anim
# mina
# emas

# %%
# get valid five-letter words

ll_words_five = set([word for word in ll_words_freq if len(word) == 5])
ll_words_five_valid = [w for w in ll_words_five if rev(w) in ll_words_five]

# %%
# produce five-letter squares

five_squares = []
for w1 in ll_words_five_valid:
    w2_match = lambda x: x[0] == w1[1] and x[-1] == w1[-2]
    for w2 in filter(w2_match, ll_words_five_valid):
        w3_match = lambda x: x[0] == w1[2] and x[1] == w2[2]
        for w3 in filter(w3_match, ll_words_five_valid):
            if w3 == rev(w3):
                square = [w1, w2, w3, rev(w2), rev(w1)]
                five_squares.append(square)

print(f'There are {len(five_squares)} that can be created from the Latin Library from five-letter words appearing more than 3x.')
# Out:
# There are 14 that can be created from the Latin Library from five-letter words appearing more than 3x.

# %%
# print random square

example = sample(five_squares, 1)[0]
for w in example:
    print(w)
# Out:
# mitis
# inani
# taxat
# inani
# sitim

# %%
# check squares against @SarahEBond tweet
# https://twitter.com/SarahEBond/status/1172256207408697344

tweet_square = ['roma', 'olim', 'milo', 'amor']
print(f'Magic square from tweet in four_square? {tweet_square in four_squares}.','\n')
for w in four_squares[four_squares.index(tweet_square)]:
    print(w)
# Out:
# Magic square from tweet in four_square? True.
#
# roma
# olim
# milo
# amor

# %%
# check squares again Sator square; CIL IV 8623 

sator_square = ['rotas', 'opera', 'tenet', 'arepo', 'sator']    
print(f'Sator square in five_square? {sator_square in five_squares}.','\n')
v = 'arepo' in ll_words_five_valid
print(f'"arepo" in ll_words_five_valid? {v}.','\n')
# Out:
# Sator square in five_square? False.
#
# "arepo" in ll_words_five_valid? False.

# %%
# print all squares

for square in four_squares+five_squares:
    print(square)
# Out:
# ['acca', 'cccc', 'cccc', 'acca']
# ['aera', 'eger', 'rege', 'area']
# ['aera', 'emor', 'rome', 'area']
# ['isim', 'sumi', 'imus', 'misi']
# ['isim', 'siti', 'itis', 'misi']
# ['isim', 'seri', 'ires', 'misi']
# ['isim', 'sami', 'imas', 'misi']
# ['isim', 'sibi', 'ibis', 'misi']
# ['isim', 'subi', 'ibus', 'misi']
# ['eure', 'uber', 'rebu', 'erue']
# ['anon', 'nemo', 'omen', 'nona']
# ['anon', 'nolo', 'olon', 'nona']
# ['asom', 'seno', 'ones', 'mosa']
# ['asom', 'sero', 'ores', 'mosa']
# ['asom', 'sino', 'onis', 'mosa']
# ['asom', 'seuo', 'oues', 'mosa']
# ['asom', 'sido', 'odis', 'mosa']
# ['arui', 'rebu', 'uber', 'iura']
# ['ensi', 'noys', 'syon', 'isne']
# ['ores', 'rege', 'eger', 'sero']
# ['ores', 'rome', 'emor', 'sero']
# ['anim', 'nati', 'itan', 'mina']
# ['iram', 'rara', 'arar', 'mari']
# ['iram', 'roga', 'agor', 'mari']
# ['iram', 'roma', 'amor', 'mari']
# ['iram', 'rosa', 'asor', 'mari']
# ['iram', 'ruta', 'atur', 'mari']
# ['esse', 'seps', 'spes', 'esse']
# ['esse', 'spes', 'seps', 'esse']
# ['esse', 'suus', 'suus', 'esse']
# ['mode', 'oded', 'dedo', 'edom']
# ['mode', 'ouid', 'diuo', 'edom']
# ['ares', 'rege', 'eger', 'sera']
# ['ares', 'rome', 'emor', 'sera']
# ['irim', 'reti', 'iter', 'miri']
# ['sara', 'agor', 'roga', 'aras']
# ['sara', 'atur', 'ruta', 'aras']
# ['sara', 'asor', 'rosa', 'aras']
# ['sara', 'amor', 'roma', 'aras']
# ['sara', 'arar', 'rara', 'aras']
# ['tate', 'aret', 'tera', 'etat']
# ['tate', 'alet', 'tela', 'etat']
# ['rara', 'agor', 'roga', 'arar']
# ['rara', 'atur', 'ruta', 'arar']
# ['rara', 'asor', 'rosa', 'arar']
# ['rara', 'amor', 'roma', 'arar']
# ['rara', 'arar', 'rara', 'arar']
# ['eret', 'rege', 'eger', 'tere']
# ['eret', 'rome', 'emor', 'tere']
# ['enim', 'nati', 'itan', 'mine']
# ['ibus', 'breu', 'uerb', 'subi']
# ['same', 'asom', 'mosa', 'emas']
# ['same', 'anim', 'mina', 'emas']
# ['same', 'aram', 'mara', 'emas']
# ['same', 'alam', 'mala', 'emas']
# ['same', 'agam', 'maga', 'emas']
# ['same', 'arem', 'mera', 'emas']
# ['suem', 'uase', 'esau', 'meus']
# ['aram', 'rara', 'arar', 'mara']
# ['aram', 'roga', 'agor', 'mara']
# ['aram', 'roma', 'amor', 'mara']
# ['aram', 'rosa', 'asor', 'mara']
# ['aram', 'ruta', 'atur', 'mara']
# ['arus', 'rebu', 'uber', 'sura']
# ['seno', 'elin', 'nile', 'ones']
# ['seno', 'euin', 'niue', 'ones']
# ['imas', 'mara', 'aram', 'sami']
# ['imas', 'mina', 'anim', 'sami']
# ['imas', 'mera', 'arem', 'sami']
# ['imas', 'mala', 'alam', 'sami']
# ['imas', 'mosa', 'asom', 'sami']
# ['imas', 'maga', 'agam', 'sami']
# ['mure', 'uber', 'rebu', 'erum']
# ['mano', 'anon', 'nona', 'onam']
# ['mano', 'asin', 'nisa', 'onam']
# ['euae', 'uena', 'aneu', 'eaue']
# ['mare', 'agor', 'roga', 'eram']
# ['mare', 'atur', 'ruta', 'eram']
# ['mare', 'asor', 'rosa', 'eram']
# ['mare', 'amor', 'roma', 'eram']
# ['mare', 'arar', 'rara', 'eram']
# ['omen', 'mode', 'edom', 'nemo']
# ['omen', 'mure', 'erum', 'nemo']
# ['omen', 'mede', 'edem', 'nemo']
# ['omen', 'mare', 'eram', 'nemo']
# ['omen', 'mine', 'enim', 'nemo']
# ['omen', 'male', 'elam', 'nemo']
# ['omen', 'mere', 'erem', 'nemo']
# ['seru', 'eger', 'rege', 'ures']
# ['seru', 'emor', 'rome', 'ures']
# ['seua', 'esau', 'uase', 'aues']
# ['††††', '††††', '††††', '††††']
# ['miri', 'iter', 'reti', 'irim']
# ['aaaa', 'acca', 'acca', 'aaaa']
# ['aaaa', 'aera', 'area', 'aaaa']
# ['aaaa', 'arra', 'arra', 'aaaa']
# ['aaaa', 'adda', 'adda', 'aaaa']
# ['aaaa', 'atta', 'atta', 'aaaa']
# ['aaaa', 'arca', 'acra', 'aaaa']
# ['aaaa', 'aaaa', 'aaaa', 'aaaa']
# ['aaaa', 'acra', 'arca', 'aaaa']
# ['aaaa', 'assa', 'assa', 'aaaa']
# ['aaaa', 'aura', 'arua', 'aaaa']
# ['aaaa', 'arua', 'aura', 'aaaa']
# ['aaaa', 'atra', 'arta', 'aaaa']
# ['aaaa', 'abba', 'abba', 'aaaa']
# ['aaaa', 'anna', 'anna', 'aaaa']
# ['aaaa', 'alla', 'alla', 'aaaa']
# ['aaaa', 'area', 'aera', 'aaaa']
# ['aaaa', 'arta', 'atra', 'aaaa']
# ['sero', 'eger', 'rege', 'ores']
# ['sero', 'emor', 'rome', 'ores']
# ['ones', 'nile', 'elin', 'seno']
# ['ones', 'niue', 'euin', 'seno']
# ['unam', 'nisa', 'asin', 'manu']
# ['unam', 'nona', 'anon', 'manu']
# ['assa', 'seps', 'spes', 'assa']
# ['assa', 'spes', 'seps', 'assa']
# ['assa', 'suus', 'suus', 'assa']
# ['issa', 'seps', 'spes', 'assi']
# ['issa', 'spes', 'seps', 'assi']
# ['issa', 'suus', 'suus', 'assi']
# ['saul', 'aneu', 'uena', 'luas']
# ['maro', 'agor', 'roga', 'oram']
# ['maro', 'atur', 'ruta', 'oram']
# ['maro', 'asor', 'rosa', 'oram']
# ['maro', 'amor', 'roma', 'oram']
# ['maro', 'arar', 'rara', 'oram']
# ['aras', 'rara', 'arar', 'sara']
# ['aras', 'roga', 'agor', 'sara']
# ['aras', 'roma', 'amor', 'sara']
# ['aras', 'rosa', 'asor', 'sara']
# ['aras', 'ruta', 'atur', 'sara']
# ['nisa', 'ibus', 'subi', 'asin']
# ['nisa', 'imas', 'sami', 'asin']
# ['nisa', 'itis', 'siti', 'asin']
# ['nisa', 'ibis', 'sibi', 'asin']
# ['nisa', 'ires', 'seri', 'asin']
# ['nisa', 'imus', 'sumi', 'asin']
# ['misi', 'ibus', 'subi', 'isim']
# ['misi', 'imas', 'sami', 'isim']
# ['misi', 'itis', 'siti', 'isim']
# ['misi', 'ibis', 'sibi', 'isim']
# ['misi', 'ires', 'seri', 'isim']
# ['misi', 'imus', 'sumi', 'isim']
# ['oram', 'rara', 'arar', 'maro']
# ['oram', 'roga', 'agor', 'maro']
# ['oram', 'roma', 'amor', 'maro']
# ['oram', 'rosa', 'asor', 'maro']
# ['oram', 'ruta', 'atur', 'maro']
# ['utem', 'tate', 'etat', 'metu']
# ['utem', 'tege', 'eget', 'metu']
# ['utem', 'time', 'emit', 'metu']
# ['utem', 'tabe', 'ebat', 'metu']
# ['utem', 'tere', 'eret', 'metu']
# ['ecce', 'cccc', 'cccc', 'ecce']
# ['sonu', 'omen', 'nemo', 'unos']
# ['sonu', 'olon', 'nolo', 'unos']
# ['etas', 'tela', 'alet', 'sate']
# ['etas', 'tera', 'aret', 'sate']
# ['aura', 'uber', 'rebu', 'arua']
# ['mara', 'agor', 'roga', 'aram']
# ['mara', 'atur', 'ruta', 'aram']
# ['mara', 'asor', 'rosa', 'aram']
# ['mara', 'amor', 'roma', 'aram']
# ['mara', 'arar', 'rara', 'aram']
# ['utis', 'teri', 'iret', 'situ']
# ['utis', 'tibi', 'ibit', 'situ']
# ['utis', 'tini', 'init', 'situ']
# ['orem', 'rege', 'eger', 'mero']
# ['orem', 'rome', 'emor', 'mero']
# ['item', 'tate', 'etat', 'meti']
# ['item', 'tege', 'eget', 'meti']
# ['item', 'time', 'emit', 'meti']
# ['item', 'tabe', 'ebat', 'meti']
# ['item', 'tere', 'eret', 'meti']
# ['eaue', 'aneu', 'uena', 'euae']
# ['aret', 'rege', 'eger', 'tera']
# ['aret', 'rome', 'emor', 'tera']
# ['emit', 'medi', 'idem', 'time']
# ['emit', 'miri', 'irim', 'time']
# ['emit', 'misi', 'isim', 'time']
# ['emit', 'muti', 'itum', 'time']
# ['emit', 'muli', 'ilum', 'time']
# ['emit', 'mati', 'itam', 'time']
# ['emit', 'mari', 'iram', 'time']
# ['emit', 'meti', 'item', 'time']
# ['emit', 'meri', 'irem', 'time']
# ['emas', 'mara', 'aram', 'same']
# ['emas', 'mina', 'anim', 'same']
# ['emas', 'mera', 'arem', 'same']
# ['emas', 'mala', 'alam', 'same']
# ['emas', 'mosa', 'asom', 'same']
# ['emas', 'maga', 'agam', 'same']
# ['sanu', 'anon', 'nona', 'unas']
# ['sanu', 'asin', 'nisa', 'unas']
# ['maus', 'aneu', 'uena', 'suam']
# ['xxxx', 'xxxx', 'xxxx', 'xxxx']
# ['mine', 'itan', 'nati', 'enim']
# ['site', 'iret', 'teri', 'etis']
# ['site', 'init', 'tini', 'etis']
# ['site', 'ibit', 'tibi', 'etis']
# ['nemo', 'enim', 'mine', 'omen']
# ['nemo', 'edem', 'mede', 'omen']
# ['nemo', 'edom', 'mode', 'omen']
# ['nemo', 'eram', 'mare', 'omen']
# ['nemo', 'elam', 'male', 'omen']
# ['nemo', 'erum', 'mure', 'omen']
# ['nemo', 'erem', 'mere', 'omen']
# ['aere', 'eger', 'rege', 'erea']
# ['aere', 'emor', 'rome', 'erea']
# ['iret', 'rege', 'eger', 'teri']
# ['iret', 'rome', 'emor', 'teri']
# ['sino', 'itan', 'nati', 'onis']
# ['seuo', 'esau', 'uase', 'oues']
# ['itam', 'tela', 'alet', 'mati']
# ['itam', 'tera', 'aret', 'mati']
# ['esne', 'syon', 'noys', 'ense']
# ['ense', 'noys', 'syon', 'esne']
# ['iure', 'uber', 'rebu', 'erui']
# ['sumi', 'unam', 'manu', 'imus']
# ['sumi', 'utem', 'metu', 'imus']
# ['edom', 'diuo', 'ouid', 'mode']
# ['edom', 'dedo', 'oded', 'mode']
# ['uena', 'elin', 'nile', 'aneu']
# ['uena', 'euin', 'niue', 'aneu']
# ['arua', 'rebu', 'uber', 'aura']
# ['aues', 'uase', 'esau', 'seua']
# ['sate', 'aret', 'tera', 'etas']
# ['sate', 'alet', 'tela', 'etas']
# ['uerb', 'eger', 'rege', 'breu']
# ['uerb', 'emor', 'rome', 'breu']
# ['esau', 'sara', 'aras', 'uase']
# ['esau', 'seua', 'aues', 'uase']
# ['esau', 'sila', 'alis', 'uase']
# ['esau', 'siba', 'abis', 'uase']
# ['esau', 'sela', 'ales', 'uase']
# ['esau', 'suta', 'atus', 'uase']
# ['esau', 'siga', 'agis', 'uase']
# ['esau', 'seba', 'abes', 'uase']
# ['esau', 'sana', 'anas', 'uase']
# ['esau', 'sala', 'alas', 'uase']
# ['esau', 'saba', 'abas', 'uase']
# ['esau', 'sita', 'atis', 'uase']
# ['esau', 'sera', 'ares', 'uase']
# ['esau', 'saga', 'agas', 'uase']
# ['esau', 'sura', 'arus', 'uase']
# ['esau', 'sica', 'acis', 'uase']
# ['esau', 'sina', 'anis', 'uase']
# ['ures', 'rege', 'eger', 'seru']
# ['ures', 'rome', 'emor', 'seru']
# ['iter', 'tate', 'etat', 'reti']
# ['iter', 'tege', 'eget', 'reti']
# ['iter', 'time', 'emit', 'reti']
# ['iter', 'tabe', 'ebat', 'reti']
# ['iter', 'tere', 'eret', 'reti']
# ['asor', 'seno', 'ones', 'rosa']
# ['asor', 'sero', 'ores', 'rosa']
# ['asor', 'sino', 'onis', 'rosa']
# ['asor', 'seuo', 'oues', 'rosa']
# ['asor', 'sido', 'odis', 'rosa']
# ['mina', 'itan', 'nati', 'anim']
# ['mera', 'eger', 'rege', 'arem']
# ['mera', 'emor', 'rome', 'arem']
# ['init', 'nati', 'itan', 'tini']
# ['amor', 'mano', 'onam', 'roma']
# ['amor', 'maro', 'oram', 'roma']
# ['amor', 'mero', 'orem', 'roma']
# ['amor', 'muro', 'orum', 'roma']
# ['amor', 'milo', 'olim', 'roma']
# ['time', 'isim', 'misi', 'emit']
# ['time', 'iram', 'mari', 'emit']
# ['time', 'itum', 'muti', 'emit']
# ['time', 'irim', 'miri', 'emit']
# ['time', 'ilum', 'muli', 'emit']
# ['time', 'item', 'meti', 'emit']
# ['time', 'itam', 'mati', 'emit']
# ['time', 'irem', 'meri', 'emit']
# ['time', 'idem', 'medi', 'emit']
# ['sana', 'anon', 'nona', 'anas']
# ['sana', 'asin', 'nisa', 'anas']
# ['anas', 'nisa', 'asin', 'sana']
# ['anas', 'nona', 'anon', 'sana']
# ['unos', 'nemo', 'omen', 'sonu']
# ['unos', 'nolo', 'olon', 'sonu']
# ['unas', 'nisa', 'asin', 'sanu']
# ['unas', 'nona', 'anon', 'sanu']
# ['erea', 'rege', 'eger', 'aere']
# ['erea', 'rome', 'emor', 'aere']
# ['emor', 'mano', 'onam', 'rome']
# ['emor', 'maro', 'oram', 'rome']
# ['emor', 'mero', 'orem', 'rome']
# ['emor', 'muro', 'orum', 'rome']
# ['emor', 'milo', 'olim', 'rome']
# ['isne', 'syon', 'noys', 'ensi']
# ['roma', 'olim', 'milo', 'amor']
# ['roma', 'oram', 'maro', 'amor']
# ['roma', 'orem', 'mero', 'amor']
# ['roma', 'orum', 'muro', 'amor']
# ['roma', 'onam', 'mano', 'amor']
# ['siti', 'iret', 'teri', 'itis']
# ['siti', 'init', 'tini', 'itis']
# ['siti', 'ibit', 'tibi', 'itis']
# ['sare', 'agor', 'roga', 'eras']
# ['sare', 'atur', 'ruta', 'eras']
# ['sare', 'asor', 'rosa', 'eras']
# ['sare', 'amor', 'roma', 'eras']
# ['sare', 'arar', 'rara', 'eras']
# ['rome', 'olim', 'milo', 'emor']
# ['rome', 'oram', 'maro', 'emor']
# ['rome', 'orem', 'mero', 'emor']
# ['rome', 'orum', 'muro', 'emor']
# ['rome', 'onam', 'mano', 'emor']
# ['teri', 'eger', 'rege', 'iret']
# ['teri', 'emor', 'rome', 'iret']
# ['unis', 'nati', 'itan', 'sinu']
# ['seri', 'eger', 'rege', 'ires']
# ['seri', 'emor', 'rome', 'ires']
# ['anis', 'nati', 'itan', 'sina']
# ['erei', 'rege', 'eger', 'iere']
# ['erei', 'rome', 'emor', 'iere']
# ['metu', 'eret', 'tere', 'utem']
# ['metu', 'emit', 'time', 'utem']
# ['metu', 'ebat', 'tabe', 'utem']
# ['metu', 'etat', 'tate', 'utem']
# ['metu', 'eget', 'tege', 'utem']
# ['etis', 'teri', 'iret', 'site']
# ['etis', 'tibi', 'ibit', 'site']
# ['etis', 'tini', 'init', 'site']
# ['reti', 'eret', 'tere', 'iter']
# ['reti', 'emit', 'time', 'iter']
# ['reti', 'ebat', 'tabe', 'iter']
# ['reti', 'etat', 'tate', 'iter']
# ['reti', 'eget', 'tege', 'iter']
# ['itis', 'teri', 'iret', 'siti']
# ['itis', 'tibi', 'ibit', 'siti']
# ['itis', 'tini', 'init', 'siti']
# ['sita', 'iret', 'teri', 'atis']
# ['sita', 'init', 'tini', 'atis']
# ['sita', 'ibit', 'tibi', 'atis']
# ['manu', 'anon', 'nona', 'unam']
# ['manu', 'asin', 'nisa', 'unam']
# ['sinu', 'itan', 'nati', 'unis']
# ['mero', 'eger', 'rege', 'orem']
# ['mero', 'emor', 'rome', 'orem']
# ['sera', 'eger', 'rege', 'ares']
# ['sera', 'emor', 'rome', 'ares']
# ['eras', 'rara', 'arar', 'sare']
# ['eras', 'roga', 'agor', 'sare']
# ['eras', 'roma', 'amor', 'sare']
# ['eras', 'rosa', 'asor', 'sare']
# ['eras', 'ruta', 'atur', 'sare']
# ['area', 'rege', 'eger', 'aera']
# ['area', 'rome', 'emor', 'aera']
# ['aneu', 'nile', 'elin', 'uena']
# ['aneu', 'niue', 'euin', 'uena']
# ['atis', 'teri', 'iret', 'sita']
# ['atis', 'tibi', 'ibit', 'sita']
# ['atis', 'tini', 'init', 'sita']
# ['orum', 'rebu', 'uber', 'muro']
# ['mosa', 'ores', 'sero', 'asom']
# ['mosa', 'ones', 'seno', 'asom']
# ['mosa', 'odis', 'sido', 'asom']
# ['mosa', 'onis', 'sino', 'asom']
# ['mosa', 'oues', 'seuo', 'asom']
# ['arar', 'rara', 'arar', 'rara']
# ['arar', 'roga', 'agor', 'rara']
# ['arar', 'roma', 'amor', 'rara']
# ['arar', 'rosa', 'asor', 'rara']
# ['arar', 'ruta', 'atur', 'rara']
# ['luas', 'uena', 'aneu', 'saul']
# ['nati', 'aret', 'tera', 'itan']
# ['nati', 'alet', 'tela', 'itan']
# ['assi', 'seps', 'spes', 'issa']
# ['assi', 'spes', 'seps', 'issa']
# ['assi', 'suus', 'suus', 'issa']
# ['iiii', 'inui', 'iuni', 'iiii']
# ['iiii', 'iuni', 'inui', 'iiii']
# ['iiii', 'iuui', 'iuui', 'iiii']
# ['iiii', 'iiii', 'iiii', 'iiii']
# ['iiii', 'illi', 'illi', 'iiii']
# ['irem', 'rege', 'eger', 'meri']
# ['irem', 'rome', 'emor', 'meri']
# ['meus', 'esau', 'uase', 'suem']
# ['sura', 'uber', 'rebu', 'arus']
# ['nona', 'omen', 'nemo', 'anon']
# ['nona', 'olon', 'nolo', 'anon']
# ['siem', 'iste', 'etsi', 'meis']
# ['siem', 'iure', 'erui', 'meis']
# ['siem', 'isne', 'ensi', 'meis']
# ['siem', 'iere', 'erei', 'meis']
# ['siem', 'iule', 'elui', 'meis']
# ['erue', 'rebu', 'uber', 'eure']
# ['rosa', 'ores', 'sero', 'asor']
# ['rosa', 'ones', 'seno', 'asor']
# ['rosa', 'odis', 'sido', 'asor']
# ['rosa', 'onis', 'sino', 'asor']
# ['rosa', 'oues', 'seuo', 'asor']
# ['onis', 'nati', 'itan', 'sino']
# ['meis', 'ensi', 'isne', 'siem']
# ['meis', 'etsi', 'iste', 'siem']
# ['meis', 'erei', 'iere', 'siem']
# ['meis', 'elui', 'iule', 'siem']
# ['meis', 'erui', 'iure', 'siem']
# ['etat', 'tela', 'alet', 'tate']
# ['etat', 'tera', 'aret', 'tate']
# ['muro', 'uber', 'rebu', 'orum']
# ['oues', 'uase', 'esau', 'seuo']
# ['asin', 'sumi', 'imus', 'nisa']
# ['asin', 'siti', 'itis', 'nisa']
# ['asin', 'seri', 'ires', 'nisa']
# ['asin', 'sami', 'imas', 'nisa']
# ['asin', 'sibi', 'ibis', 'nisa']
# ['asin', 'subi', 'ibus', 'nisa']
# ['iere', 'eger', 'rege', 'erei']
# ['iere', 'emor', 'rome', 'erei']
# ['eram', 'rara', 'arar', 'mare']
# ['eram', 'roga', 'agor', 'mare']
# ['eram', 'roma', 'amor', 'mare']
# ['eram', 'rosa', 'asor', 'mare']
# ['eram', 'ruta', 'atur', 'mare']
# ['sami', 'asom', 'mosa', 'imas']
# ['sami', 'anim', 'mina', 'imas']
# ['sami', 'aram', 'mara', 'imas']
# ['sami', 'alam', 'mala', 'imas']
# ['sami', 'agam', 'maga', 'imas']
# ['sami', 'arem', 'mera', 'imas']
# ['situ', 'iret', 'teri', 'utis']
# ['situ', 'init', 'tini', 'utis']
# ['situ', 'ibit', 'tibi', 'utis']
# ['mati', 'aret', 'tera', 'itam']
# ['mati', 'alet', 'tela', 'itam']
# ['sina', 'itan', 'nati', 'anis']
# ['tera', 'eger', 'rege', 'aret']
# ['tera', 'emor', 'rome', 'aret']
# ['cccc', 'cccc', 'cccc', 'cccc']
# ['mari', 'agor', 'roga', 'iram']
# ['mari', 'atur', 'ruta', 'iram']
# ['mari', 'asor', 'rosa', 'iram']
# ['mari', 'amor', 'roma', 'iram']
# ['mari', 'arar', 'rara', 'iram']
# ['onam', 'nisa', 'asin', 'mano']
# ['onam', 'nona', 'anon', 'mano']
# ['tere', 'eger', 'rege', 'eret']
# ['tere', 'emor', 'rome', 'eret']
# ['mere', 'eger', 'rege', 'erem']
# ['mere', 'emor', 'rome', 'erem']
# ['itan', 'tela', 'alet', 'nati']
# ['itan', 'tera', 'aret', 'nati']
# ['uase', 'atus', 'suta', 'esau']
# ['uase', 'ares', 'sera', 'esau']
# ['uase', 'arus', 'sura', 'esau']
# ['uase', 'alis', 'sila', 'esau']
# ['uase', 'ales', 'sela', 'esau']
# ['uase', 'aras', 'sara', 'esau']
# ['uase', 'abas', 'saba', 'esau']
# ['uase', 'acis', 'sica', 'esau']
# ['uase', 'aues', 'seua', 'esau']
# ['uase', 'abis', 'siba', 'esau']
# ['uase', 'anas', 'sana', 'esau']
# ['uase', 'anis', 'sina', 'esau']
# ['uase', 'atis', 'sita', 'esau']
# ['uase', 'alas', 'sala', 'esau']
# ['uase', 'agas', 'saga', 'esau']
# ['uase', 'agis', 'siga', 'esau']
# ['uase', 'abes', 'seba', 'esau']
# ['erui', 'rebu', 'uber', 'iure']
# ['subi', 'uerb', 'breu', 'ibus']
# ['breu', 'rege', 'eger', 'uerb']
# ['breu', 'rome', 'emor', 'uerb']
# ['suam', 'uena', 'aneu', 'maus']
# ['meti', 'eret', 'tere', 'item']
# ['meti', 'emit', 'time', 'item']
# ['meti', 'ebat', 'tabe', 'item']
# ['meti', 'etat', 'tate', 'item']
# ['meti', 'eget', 'tege', 'item']
# ['erum', 'rebu', 'uber', 'mure']
# ['tini', 'itan', 'nati', 'init']
# ['ires', 'rege', 'eger', 'seri']
# ['ires', 'rome', 'emor', 'seri']
# ['meri', 'eger', 'rege', 'irem']
# ['meri', 'emor', 'rome', 'irem']
# ['arem', 'rege', 'eger', 'mera']
# ['arem', 'rome', 'emor', 'mera']
# ['erem', 'rege', 'eger', 'mere']
# ['erem', 'rome', 'emor', 'mere']
# ['imus', 'metu', 'utem', 'sumi']
# ['imus', 'manu', 'unam', 'sumi']
# ['iura', 'uber', 'rebu', 'arui']
# ['atras', 'taeda', 'refer', 'adeat', 'sarta']
# ['satis', 'alati', 'taxat', 'itala', 'sitas']
# ['sitas', 'itala', 'taxat', 'alati', 'satis']
# ['enisa', 'nonis', 'inani', 'sinon', 'asine']
# ['maiam', 'aenea', 'inani', 'aenea', 'maiam']
# ['eatis', 'alati', 'taxat', 'itala', 'sitae']
# ['asine', 'sinon', 'inani', 'nonis', 'enisa']
# ['sitis', 'inani', 'taxat', 'inani', 'sitis']
# ['sarta', 'adeat', 'refer', 'taeda', 'atras']
# ['sitae', 'itala', 'taxat', 'alati', 'eatis']
# ['temet', 'etate', 'malam', 'etate', 'temet']
# ['temet', 'etate', 'maiam', 'etate', 'temet']
# ['mitis', 'inani', 'taxat', 'inani', 'sitim']
# ['sitim', 'inani', 'taxat', 'inani', 'mitis']
