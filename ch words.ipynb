# %%
from cltk.corpus.latin import latinlibrary

# %%
words = [word for word in latinlibrary.words() if 'ch' in word]

# %%
words = sorted(set(words))

# %%
len(words)
# Out:
# 6245

# %%
print(words)
# Out:
# ["'Achaeis", "'Achaica", "'Achate", "'Acheloe", "'Acherunsia", "'Achivi", "'Anacharsis", "'Anchisa", "'Antioche", "'Antiocho", "'Antiochus", "'Apochrisarius", "'Brachia", "'Cechinus", "'Colchos", "'Geschichtschreiber", "'Geschiedkundige", "'Gracchus", "'Inachia", "'Inachidae", "'Mnesilochus", "'Monarcha", "'Psyche", "'Pulchra", "'Richaredus", "'achalino", "'amacho", "'apeschoinismenos", "'arche", "'archetypo", "'architectus", "'bacchari", "'chaere", "'characterismo", "'chio", "'echontas", "'echoreuse", "'echousi", "'eschonto", "'hydrechoou", "'moecha", "'occhiover", "'ouch", "'ouchi", "'pulcher", "'pulchros", "'schemata", "'scholastici", '+Calimachus+', '>Periocha', '?Eunuchus', 'Abadelbach', 'Abadelbachi', 'Abdemelech', 'Abimalech', 'Abimelech', 'Ach', 'Ach&aelig', 'Acha', 'Acha-moth', 'Achab', 'Achab.', 'Achademia', 'Achademiam', 'Achademicis', 'Achaea', 'Achaeae', 'Achaeas', 'Achaei', 'Achaeiadas', 'Achaeis', 'Achaeis&#151', 'Achaemenes', 'Achaemeniae', 'Achaemeniam', 'Achaemenias
# ...
